# %% [markdown]
# # Wood & Poole Data Analysis
# This data is aquired from US Census
# Data in this overview is from 2022.
# The forcast represents varieus  attributes.

# %%
# Import libraries
import pandas as pd
import os

# %%
# Create an empty master DataFrame
master_df = pd.DataFrame()

# Define the directory where your CSV files are located
csv_directory = "L:/Belachew/lab/P/WoodAndPool/2022/Demographic/SPC"

# Get a list of CSV files in the directory
csv_files = [filename for filename in os.listdir(csv_directory) if filename.endswith(".CSV")]

# Check if any CSV files are present
if not csv_files:
    print("No CSV files found in the specified directory.")
else:
    # Iterate through each CSV file in the directory
    for filename in csv_files:
        file_path = os.path.join(csv_directory, filename)

        # Load the CSV file into a DataFrame and skip the first two rows and last 36 rows
        df = pd.read_csv(file_path, skiprows=[0, 1], skipfooter=36, engine='python')

        # Transpose the DataFrame and use the second row as the column names
        df = df.T
        new_header = df.iloc[0]
        df = df[1:]
        df.columns = new_header

        # Add a new column called "county name" and replace first 3 characters with blank
        county_Code = os.path.splitext(filename)[0]
        df["FIPSCode"] = county_Code[3:]
        #df["FIPSCode"] = df["FIPSCode"].astype(str)
        # Replace the Insex with"Year" as column name
        df.index.names = ['Year']
        
        # Replace the n.a. with black
        df = df.replace('n.a.',"")      
        

       
       
        # Append the DataFrame to the master DataFrame
        master_df = master_df.append(df, ignore_index=False)
        

        # Merge (join) the "master_df" with the "county list" DataFrame based on "FIPSCode"
#county_list_file = "L:/Belachew/lab/P/WoodAndPool/2022/Demographic/SPC/PA_FIPSCODE.xlsx"  # Replace with the actual path to your county list file
#county_list_df = pd.read_excel(county_list_file)
#master_df = master_df.merge(county_list_df, on="FIPSCode", how="left")



# Convert the "FIPSCode" column to string in both DataFrames
#master_df["FIPSCode"] = master_df["FIPSCode"].astype(str)

# Merge (join) the "master_df" with the "county list" DataFrame based on "FIPSCode"
county_list_file = "L:/Belachew/lab/P/WoodAndPool/2022/Demographic/SPC/PA_FIPSCODE.xlsx"  # Replace with the actual path to your county list file
county_list_df = pd.read_excel(county_list_file)
county_list_df["FIPSCode"] = county_list_df["FIPSCode"].astype(str)

master_df.reset_index(inplace=True)
master_df = pd.merge(master_df, county_list_df, on="FIPSCode", how="left")

# Print the master DataFrame (for debugging purposes)
# print(master_df)
# Out:
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(df, ignore_index=False)
# C:\Users\ayele\AppData\Local\Temp\ipykernel_7844\752996317.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   master_df.reset_index(inplace=True)

# %%
# Export the master DataFrame to Excel
output_excel_file = "L:/Belachew/lab/P/WoodAndPool/2022/Demographic/SPC/master_dataframe.xlsx"
master_df.to_excel(output_excel_file, index=False)

# %%
# view
df.head(5)
# Out:
#      TOTAL POPULATION, ALL AGES (in thousands)  \
# Year
# 1969                                   374.580
# 1970                                   377.482
# 1971                                   379.856
# 1972                                   382.048
# 1973                                   382.574
#
#        TOTAL POPULATION AGE UNDER 5 YEARS (in thousands)  \
# Year
# 1969
# 1970                                             29.772
# 1971                                             29.465
# 1972                                             28.838
# 1973                                             27.933
#
#          TOTAL POPULATION AGE UNDER 1 YEAR (in thousands)  \
# Year
# 1969
# 1970                                              5.562
# 1971                                              5.619
# 1972                                              5.079
# 1973                                              4.729
#
#          TOTAL POPULATION AGE 1 YEAR (in thousands)  \
# Year
# 1969
# 1970                                          5.784
# 1971                                          5.865
# 1972                                          5.893
# 1973                                          5.274
#
#          TOTAL POPULATION AGE 2 YEARS (in thousands)  \
# Year
# 1969
# 1970                                           5.791
# 1971                                           5.790
# 1972                                           5.873
# 1973                                           5.877
#
#          TOTAL POPULATION AGE 3 YEARS (in thousands)  \
# Year
# 1969
# 1970                                           6.156
# 1971                                           5.936
# 1972                                           5.946
# 1973                                           6.011
#
#          TOTAL POPULATION AGE 4 YEARS (in thousands)  \
# Year
# 1969
# 1970                                           6.479
# 1971                                           6.255
# 1972                                           6.047
# 1973                                           6.042
#
#        TOTAL POPULATION AGE 5 to 9 YEARS (in thousands)  \
# Year
# 1969
# 1970                                             35.172
# 1971                                             33.969
# 1972                                             32.818
# 1973                                             31.523
#
#          TOTAL POPULATION AGE 5 YEARS (in thousands)  \
# Year
# 1969
# 1970                                           6.790
# 1971                                           6.335
# 1972                                           6.138
# 1973                                           5.919
#
#          TOTAL POPULATION AGE 6 YEARS (in thousands)  ...  \
# Year                                                  ...
# 1969                                                  ...
# 1970                                           6.891  ...
# 1971                                           6.553  ...
# 1972                                           6.152  ...
# 1973                                           5.965  ...
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 79 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#        HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 80 to 84 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 80 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 81 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 82 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 83 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#          HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 84 YEARS (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#        HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 85 YEARS and OVER (in thousands)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#      HISPANIC or LATINO FEMALE POPULATION of ANY RACE MEDIAN AGE (in years)  \
# Year
# 1969
# 1970
# 1971
# 1972
# 1973
#
#      FIPSCode
# Year
# 1969    42129
# 1970    42129
# 1971    42129
# 1972    42129
# 1973    42129
#
# [5 rows x 1891 columns]

# %%
# View 

master_df.head(5)
# Out:
#    Year TOTAL POPULATION, ALL AGES (in thousands)  \
# 0  1969                                  1606.592
# 1  1970                                  1602.663
# 2  1971                                  1593.741
# 3  1972                                  1573.661
# 4  1973                                  1549.171
#
#     TOTAL POPULATION AGE UNDER 5 YEARS (in thousands)  \
# 0
# 1                                            115.661
# 2                                            113.216
# 3                                            108.775
# 4                                            103.537
#
#       TOTAL POPULATION AGE UNDER 1 YEAR (in thousands)  \
# 0
# 1                                             22.580
# 2                                             22.637
# 3                                             20.167
# 4                                             18.496
#
#       TOTAL POPULATION AGE 1 YEAR (in thousands)  \
# 0
# 1                                         22.774
# 2                                         22.756
# 3                                         22.495
# 4                                         19.825
#
#       TOTAL POPULATION AGE 2 YEARS (in thousands)  \
# 0
# 1                                          22.121
# 2                                          21.913
# 3                                          21.812
# 4                                          21.551
#
#       TOTAL POPULATION AGE 3 YEARS (in thousands)  \
# 0
# 1                                          23.479
# 2                                          22.389
# 3                                          21.999
# 4                                          21.796
#
#       TOTAL POPULATION AGE 4 YEARS (in thousands)  \
# 0
# 1                                          24.707
# 2                                          23.521
# 3                                          22.302
# 4                                          21.869
#
#     TOTAL POPULATION AGE 5 to 9 YEARS (in thousands)  \
# 0
# 1                                            140.275
# 2                                            133.582
# 3                                            126.125
# 4                                            118.462
#
#       TOTAL POPULATION AGE 5 YEARS (in thousands)  ...  \
# 0                                                  ...
# 1                                          26.125  ...
# 2                                          24.117  ...
# 3                                          22.832  ...
# 4                                          21.608  ...
#
#     HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 80 to 84 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#       HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 80 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#       HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 81 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#       HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 82 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#       HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 83 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#       HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 84 YEARS (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#     HISPANIC or LATINO FEMALE POPULATION of ANY RACE AGE 85 YEARS and OVER (in thousands)  \
# 0
# 1
# 2
# 3
# 4
#
#   HISPANIC or LATINO FEMALE POPULATION of ANY RACE MEDIAN AGE (in years)  \
# 0
# 1
# 2
# 3
# 4
#
#   FIPSCode CountyName
# 0    42003  Allegheny
# 1    42003  Allegheny
# 2    42003  Allegheny
# 3    42003  Allegheny
# 4    42003  Allegheny
#
# [5 rows x 1893 columns]

# %% [markdown]
# # Plot the data into Graphs

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
#sns.lineplot(All_data = All_data, x = 'Year', y = 'TOTAL POPULATION, ALL AGES (in thousands)', hue = 'CountyName')
#lt.show()

sns.set_style('darkgrid')

# %%
#All_data = # Read Back the excel files
All_data= pd.read_excel("L:/Belachew/lab/P/WoodAndPool/2022/Demographic/SPC/master_dataframe.xlsx")

# %%
g = sns.FacetGrid(All_data, col='CountyName', col_wrap=5, sharey = False, height=4, aspect=1.2) #, ylim = (50, 1700), )
g.map_dataframe(sns.lineplot, x='Year', y= 'TOTAL FEMALE POPULATION, ALL AGES (in thousands)')
g.set_axis_labels('Year', 'Population in thousands')
g.set_titles (col_template = '{col_name} County, PA, Total Female Population')

# New code to add a source to each facet grid
footnote_text = "Data source: Wood and Poole, Census 2022"

for ax in g.axes.flat:
    ax.text(0.25, -0.2, footnote_text, transform=ax.transAxes, ha="center", fontsize=8, color='gray')
    
    
    # Set x-axis tick interval to 10 years
    ax.xaxis.set_major_locator(ticker.MultipleLocator(base=10))

#plt.savefig('Total Female Population _facet_grid_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot male and female together

g = sns.FacetGrid(All_data, col='CountyName', col_wrap=5, sharey = False, height=4, aspect=1.2) #, ylim = (50, 1700), )
g.map_dataframe(sns.lineplot, x='Year', y= 'TOTAL MALE POPULATION, ALL AGES (in thousands)',color='blue', label='Male Population')
g.map_dataframe(sns.lineplot, x='Year', y= 'TOTAL FEMALE POPULATION, ALL AGES (in thousands)',color='red', label='Female Population')
g.set_axis_labels('Year', 'Population in thousands')
g.set_titles (col_template = '{col_name} County, PA, Total Male & Female Population')

# New code to add a source to each facet grid
footnote_text = "Data source: Wood and Poole, Census 2022"

for ax in g.axes.flat:
    ax.text(0.25, -0.2, footnote_text, transform=ax.transAxes, ha="center", fontsize=8, color='gray')
    
    
  


  # Set x-axis tick interval to 10 years
    ax.xaxis.set_major_locator(ticker.MultipleLocator(base=10))
    
    # Add a legend to the current facet in the bottom middle
    ax.legend(loc='lower center', fontsize=6)

    # Move the legend to the desired position
    legend = ax.get_legend()
    legend.set_bbox_to_anchor((0.5, -0.015))  # Adjust the second value to control the vertical position




plt.savefig('Total Male and Female Population _facet_grid_plot.png', dpi=300, bbox_inches='tight')
plt.show()
